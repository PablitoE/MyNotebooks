# %% [markdown]
# # HoloICE
#
# ## Aims
#
# - Quantify cloud microphysical processes using a high-speed holographic imaging system.
# - Apply to numerical models to assess the impact on modelled cloud properties.
#
# ### Motivation
#
# Get insight on effects of cloud microphysics on precipitation formation, storm electrification processes, and radiative transfer for getting more realistic simulations of clouds. Secondary ice processes increase the number of ice particles in clouds by fragmenting existing ice particles in various ways:
# - freezing and shattering of water drops,
# - rime splintering,
# - following ice crystal collisions,
# - fragmentation of ice during sublimation.
#
# ### Objectives
#
# 1. Develop a state-of-the science high-speed holographic imaging system for laboratory studies of cloud microphysical processes
# 2. Develop a quantitative description of the rime splintering process
# 3. Develop a quantitative description of the droplet freezing-shattering process
# 4. Develop numerical representations of rime-splintering and droplet-freezing processes in a variety of frameworks, including the Met Office CASIM scheme.
# 5. Assess the impact of rime-splintering and droplet freezing-shattering processes on real cloud systems.
#
# ## 1. High-Speed Digital Holographic Microscopy
#
# Imaging with pulsed laser at wavelength 355 nm, high speed cameras, and high resolution (low frame rate).
#
# ### Calibration
#
# 1. Static
# 2. Linear motion
# 3. Complex known structure of optical traps
#
# ### Tracking
#
# 1. Reconstruction and identification of particles
# 2. Track recognized particles
# 3. Detect formation of new particles
#
# ## 2. Rime splintering
#
# 1. Water droplets (20 um) impact on ice target.
#     - delivering droplets
#     - cold stage
#     - cold shearing air
# 2. Large supercooled water droplets are accreted by rimed ice particles in the temperature range -3 to -8 °C
#
#
# ## 3. Droplet freezing-shattering
#
# 1. Large millimiter sized water droplets acoustically levitated:
# 2. 85 um with solid inclusions
#
# - enclosure for DHM capable of working at low temperatures
# - delivery of droplets by spray or syringe
#
# ## 4. Numerical representations
#
# ## 5. Impact on real cloud systems

# %% [markdown]
# # First project meeting with Rachel
#
# ## Planning meeting 31/3/2021
#
# Scheme of meeting:
# 1. Brief introduction of the aims and motivations of the project
# 2. Introduction of each of us and our rol, and backgrounds (previous related work)
# 3. State of WP1: Development of High-Speed Digital Holographic Microscope
# 4. Next goals: freezing droplets and rime splinttering. Questions
#
# ## Questions
#
# 1. Which of the two processes you think it would have more impact in lowering uncertainties of simulation models?
# 2. Is there another aspect that should be used to decide where to put more time?
# 3. Rime splintering, large supercooled water droplets impacted by ice particles, freezes and shatters
#     1. LARGE : what dimensions?
#     2. SUPERCOOLED : what range of temperatures?
# 4. Rime splintering, ways of recreating:
#     1. How to deliver droplets? Nanodispenser, syringe, printer inkjet
#     2. Cold stage with printed structure and cool sheath air, how are they thought of as riming? Is this done in the cold room?
#     3. Chamber with generated ice particles in lower part. Paul talked about trying to generate it using the mist generator. Dates? It would be great to get the best configuration (drop trajectory and velocity, depth of cloud). That way we could put the sampled volume of the DHM where is more likely to get the process.
#     4. Does it make sense having the supercooled droplet levitating and immersed on ice particles flow or shot at with ice particles? How can we shoot ice particles?
# 5. Freezing/shattering droplets. Large millimeter size droplets (around -25°C) or smaller droplets (85 $\mu$m) with inclusions at -10°C to -15°C.
#     1. In case of using a levitator, we should add an air flow. How can we create a dry air flow?
#     2. Wind tunnel seems optimum. What can we use? Stability? Dimensions of set-up interfering with flow?
#     3. Experiments to find conditions to shatter? Freezing temperature, composition.
#     4. Does it make sense looking at the mist as it freezes and tracking many particles until one shatters?
# 6. What do you think about using Google Docs to share thoughts about the project?
